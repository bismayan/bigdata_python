# %% [markdown]
# ## import pandas as pd

# %%
# %matplotlib inline
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import matplotlib.pyplot as plt

# %%
set_option("display.max_rows", 16)
LARGE_FIGSIZE=(12,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cc918a104ff6> in <module>()
# ----> 1 set_option("display.max_rows", 16)
#       2 LARGE_FIGSIZE=(12,8)
#
# NameError: name 'set_option' is not defined

# %%
from pandas import set_option
set_option("display.max_rows", 16)
LARGE_FIGSIZE=(12,8)

# %%
# %cd /Users/bismayan/Dropbox/bigdata_python/pandas_tutorial-master/demos/climate_timeseries/
# %ls

# %%
pd.read_table?

# %%
filename="data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat"
full_globe_temp=pd.read_table(filename)
full_globe_temp

# %%
full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0,parse_dates=True)
full_globe_temp

# %%
full_globe_temp.shape

# %%
full_globe_temp.size

# %%
plt.plot(full_globe_temp[:,0],full_globe_temp[:,1])

# %%
full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0)

# %%
full_globe_temp

# %%
plt.plot(full_globe_temp[:,0],full_globe_temp[:,1])

# %%
%

# %%
full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0,parse_dates=True)

# %%
full_globe_temp

# %%
full_globe_temp.type

# %%
type?

# %%
type(full_globe_temp)

# %%
full_globe_temp.shape

# %%
full_globe_temp

# %%
type?

# %%
mp=pd.read_table("data/temperatures/GLB.Ts+dSST.txt",sep='\s+',skiprows=7,skip_footer=11,engine="python")
mp

# %%
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt")

# %%
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='\s+')

# %%
co2

# %%
pd.read_table?

# %%
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='\s+',parse_dates=[[0,1]])

# %%
co2

# %%
southern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_nh.txt",sep='\s+')
southern_sea_level

# %%
southern_sea_level

# %%
southern_sea_level
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8f30e2c73b93> in <module>()
# ----> 1 southern_sea_level
#
# NameError: name 'southern_sea_level' is not defined

# %%
southern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_nh.txt",sep='\s+')
southern_sea_level
# Out:
#           year  msl_ib(mm)  #version_2016rel1
# 0    1992.9323      13.717                NaN
# 1    1992.9595       1.328                NaN
# 2    1992.9866     -13.375                NaN
# 3    1993.0138     -24.723                NaN
# 4    1993.0409     -29.231                NaN
# 5    1993.0681     -32.538                NaN
# 6    1993.0952     -35.588                NaN
# 7    1993.1223     -26.579                NaN
# 8    1993.1495     -29.622                NaN
# 9    1993.1766     -34.527                NaN
# 10   1993.2038     -34.250                NaN
# 11   1993.2309     -28.518                NaN
# 12   1993.2581     -30.437                NaN
# 13   1993.2852     -21.371                NaN
# 14   1993.3124     -19.196                NaN
# 15   1993.3395     -23.758                NaN
# 16   1993.3667     -23.628                NaN
# 17   1993.3938     -17.808                NaN
# 18   1993.4210     -10.085                NaN
# ...

# %%
c02
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ac874349bf25> in <module>()
# ----> 1 c02
#
# NameError: name 'c02' is not defined

# %%
co2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-58525e3d068d> in <module>()
# ----> 1 co2
#
# NameError: name 'co2' is not defined

# %%
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt")

# %%
co2
# Out:
#        year month     decimal     average       trend
# 0      1980     1    1980.042      338.45      337.82
# 1      1980     2    1980.125      339.17      338.12
# 2      1980     3    1980.208      339.49      338.14
# 3      1980     4    1980.292      339.87      338.25
# 4      1980     5    1980.375      340.30      338.78
# 5      1980     6    1980.458      339.86      339.08
# 6      1980     7    1980.542      338.32      339.17
# 7      1980     8    1980.625      337.11      339.37
# 8      1980     9    1980.708      336.95      339.33
# 9      1980    10    1980.792      337.71      339.06
# 10     1980    11    1980.875      338.83      339.17
# 11     1980    12    1980.958      339.55      339.32
# 12     1981     1    1981.042      340.10      339.47
# 13     1981     2    1981.125      340.66      339.61
# 14     1981     3    1981.208      341.29      339.94
# 15     1981     4    1981.292      341.57      339.96
# ...

# %%
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='/s+',parse_dates=[[0,1]])
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-9481f59944d1> in <module>()
# ----> 1 co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='/s+',parse_dates=[[0,1]])
#
# ...

# %%
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='/s+',parse_dates=[[0,1]],engine="python")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-4050a42a8aca> in <module>()
# ----> 1 co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='/s+',parse_dates=[[0,1]],engine="python")
#
# ...

# %%
import pandas as pd

# %%
northern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_nh.txt",sep='\s+')

# %%
northern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_sh.txt",sep='\s+')

# %%
northern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_nh.txt",sep='\s+')

# %%
southern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_nh.txt",sep='\s+')

# %%
southern_sea_level
# Out:
#           year  msl_ib(mm)  #version_2016rel1
# 0    1992.9323      13.717                NaN
# 1    1992.9595       1.328                NaN
# 2    1992.9866     -13.375                NaN
# 3    1993.0138     -24.723                NaN
# 4    1993.0409     -29.231                NaN
# 5    1993.0681     -32.538                NaN
# 6    1993.0952     -35.588                NaN
# 7    1993.1223     -26.579                NaN
# 8    1993.1495     -29.622                NaN
# 9    1993.1766     -34.527                NaN
# 10   1993.2038     -34.250                NaN
# 11   1993.2309     -28.518                NaN
# 12   1993.2581     -30.437                NaN
# 13   1993.2852     -21.371                NaN
# 14   1993.3124     -19.196                NaN
# 15   1993.3395     -23.758                NaN
# 16   1993.3667     -23.628                NaN
# 17   1993.3938     -17.808                NaN
# 18   1993.4210     -10.085                NaN
# ...

# %%
full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0,parse_dates=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-19ec40dcef7d> in <module>()
# ----> 1 full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0,parse_dates=True)
#
# NameError: name 'filename' is not defined

# %%
# %cd ~/Dropbox/bigdata_python/pandas_tutorial-master/demos/climate_timeseries/
ls

# %%
# %ls

# %%
filename="data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat"
full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0,parse_dates=True)

# %%
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='/s+',parse_dates=[[0,1]],engine="python")

# %%
# %cd ~/Dropbox/bigdata_python/pandas_tutorial-master/demos/climate_timeseries/

# %%
import pandas as pd
import numpy as np

# %%
northern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_nh.txt",sep='\s+')

# %%
southern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_sh.txt",sep='\s+')

# %%
filename="data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat"
full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0,parse_dates=True)

# %%
full_globe_temp

# %%
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='\s+',parse_dates=[[0,1]])

# %%
co2

# %%
giss_temp=pd.read_table("data/temperatures/GLB.Ts+dSST.txt",sep="/s+",skiprows=7,skip_footer=11,engine="python")

# %%
giss_temp

# %%
giss_temp=pd.read_table("data/temperatures/GLB.Ts+dSST.txt",sep="\s+",skiprows=7,skip_footer=11,engine="python")

# %%
giss_temp

# %%
pd.read_table?

# %%
global_sea_level=pd.read_table("http://sealevel.colorado.edu/files/2015_rel2/sl_ns_global.txt",sep='\s+')")

# %%
global_sea_level=pd.read_table("http://sealevel.colorado.edu/files/2015_rel2/sl_ns_global.txt",sep='\s+')

# %%
global_sea_level

# %%
table_list=pd.read_html("http://www.psms1.org/data/obtaining/")

# %%
co2

# %%
co2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-58525e3d068d> in <module>()
# ----> 1 co2
#
# NameError: name 'co2' is not defined

# %%
giss_temp=pd.read_table("data/temperatures/GLB.Ts+dSST.txt",sep="\s+",skiprows=7,skip_footer=11,engine="python")

# %%
global_sea_level=pd.read_table("http://sealevel.colorado.edu/files/2015_rel2/sl_ns_global.txt",sep='\s+')

# %%
northern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_nh.txt",sep='\s+')

# %%
southern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_sh.txt",sep='\s+')

# %%
filename="data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat"
full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0,parse_dates=True)

# %%
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='\s+',parse_dates=[[0,1]])

# %%
table_list=pd.read_html("http://www.psms1.org/data/obtaining/")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-9cbe1126f751> in <module>()
# ----> 1 table_list=pd.read_html("http://www.psms1.org/data/obtaining/")
#
# /usr/local/lib/python2.7/site-packages/pandas/io/html.pyc in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     868     _validate_header_arg(header)
#     869     return _parse(flavor, io, match, header, index_col, skiprows,
# --> 870                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# /usr/local/lib/python2.7/site-packages/pandas/io/html.pyc in _parse(flavor, io, match, header, index_col, skiprows, parse_dates, tupleize_cols, thousands, attrs, encoding)
#     720     retained = None
#     721     for flav in flavor:
# --> 722         parser = _parser_dispatch(flav)
# ...

# %%
table_list=pd.read_html("http://www.psms1.org/data/obtaining/")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-17-9cbe1126f751> in <module>()
# ----> 1 table_list=pd.read_html("http://www.psms1.org/data/obtaining/")
#
# /usr/local/lib/python2.7/site-packages/pandas/io/html.pyc in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     868     _validate_header_arg(header)
#     869     return _parse(flavor, io, match, header, index_col, skiprows,
# --> 870                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# /usr/local/lib/python2.7/site-packages/pandas/io/html.pyc in _parse(flavor, io, match, header, index_col, skiprows, parse_dates, tupleize_cols, thousands, attrs, encoding)
#     720     retained = None
#     721     for flav in flavor:
# --> 722         parser = _parser_dispatch(flav)
# ...

# %%
table_list=pd.read_html("http://www.psms1.org/data/obtaining/")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-9cbe1126f751> in <module>()
# ----> 1 table_list=pd.read_html("http://www.psms1.org/data/obtaining/")
#
# /usr/local/lib/python2.7/site-packages/pandas/io/html.pyc in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     868     _validate_header_arg(header)
#     869     return _parse(flavor, io, match, header, index_col, skiprows,
# --> 870                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# /usr/local/lib/python2.7/site-packages/pandas/io/html.pyc in _parse(flavor, io, match, header, index_col, skiprows, parse_dates, tupleize_cols, thousands, attrs, encoding)
#     720     retained = None
#     721     for flav in flavor:
# --> 722         parser = _parser_dispatch(flav)
# ...

# %%
giss_temp=pd.read_table("data/temperatures/GLB.Ts+dSST.txt",sep="\s+",skiprows=7,skip_footer=11,engine="python")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c795402fc8fc> in <module>()
# ----> 1 giss_temp=pd.read_table("data/temperatures/GLB.Ts+dSST.txt",sep="\s+",skiprows=7,skip_footer=11,engine="python")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
giss_temp=pd.read_table("data/temperatures/GLB.Ts+dSST.txt",sep="\s+",skiprows=7,skip_footer=11,engine="python")

# %%
global_sea_level=pd.read_table("http://sealevel.colorado.edu/files/2015_rel2/sl_ns_global.txt",sep='\s+')
northern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_nh.txt",sep='\s+')
southern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_sh.txt",sep='\s+')
filename="data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat"
full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0,parse_dates=True)
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='\s+',parse_dates=[[0,1]])
table_list=pd.read_html("http://www.psms1.org/data/obtaining/")
# Out:
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-5-ec8cc71f983c> in <module>()
#       5 full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0,parse_dates=True)
#       6 co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='\s+',parse_dates=[[0,1]])
# ----> 7 table_list=pd.read_html("http://www.psms1.org/data/obtaining/")
#
# /usr/local/lib/python2.7/site-packages/pandas/io/html.pyc in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     868     _validate_header_arg(header)
#     869     return _parse(flavor, io, match, header, index_col, skiprows,
# --> 870                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# ...

# %%
table_list=pd.read_html("data/sea_levels/Obtaining Tide Gauge Data.html")

# %%
table_list
# Out:
# [                                  0   \
#  0                                NaN
#  1                                NaN
#  2                                FEB
#  3                                NaN
#  4                               2014
#  5  58 captures  18 Apr 10 - 3 Apr 15
#
#                                                    1     2   \
#  0  FEB  APR  May  3  2014  2015  2016  58 capture...   NaN
#  1                 FEB  APR  May  3  2014  2015  2016   FEB
#  2                                                APR   May
#  3                                                  3   NaN
#  4                                               2015  2016
#  5                                                NaN   NaN
#
#                                     3    4    5    6   7       8       9   \
#  0  FEB  APR  May  3  2014  2015  2016  FEB  APR  May NaN     3.0     NaN
#  1                                 APR  May  NaN    3 NaN  2014.0  2015.0
# ...

# %%
local_sea_level_stations=table_list[0]

# %%
local_sea_level_stations
# Out:
#                                   0   \
# 0                                NaN
# 1                                NaN
# 2                                FEB
# 3                                NaN
# 4                               2014
# 5  58 captures  18 Apr 10 - 3 Apr 15
#
#                                                   1     2   \
# 0  FEB  APR  May  3  2014  2015  2016  58 capture...   NaN
# 1                 FEB  APR  May  3  2014  2015  2016   FEB
# 2                                                APR   May
# 3                                                  3   NaN
# 4                                               2015  2016
# 5                                                NaN   NaN
#
#                                    3    4    5    6   7       8       9   \
# 0  FEB  APR  May  3  2014  2015  2016  FEB  APR  May NaN     3.0     NaN
# 1                                 APR  May  NaN    3 NaN  2014.0  2015.0
# ...

# %%
len(table_list)
# Out:
# 4

# %%
table_list
# Out:
# [                                  0   \
#  0                                NaN
#  1                                NaN
#  2                                FEB
#  3                                NaN
#  4                               2014
#  5  58 captures  18 Apr 10 - 3 Apr 15
#
#                                                    1     2   \
#  0  FEB  APR  May  3  2014  2015  2016  58 capture...   NaN
#  1                 FEB  APR  May  3  2014  2015  2016   FEB
#  2                                                APR   May
#  3                                                  3   NaN
#  4                                               2015  2016
#  5                                                NaN   NaN
#
#                                     3    4    5    6   7       8       9   \
#  0  FEB  APR  May  3  2014  2015  2016  FEB  APR  May NaN     3.0     NaN
#  1                                 APR  May  NaN    3 NaN  2014.0  2015.0
# ...

# %%
table_list1=pd.read_html("data/sea_levels/Obtaining Tide Gauge Data.html")

# %%
len(table_list1)
# Out:
# 4

# %%
table_list1=pd.read_html("data/sea_levels/Obtaining Tide Gauge Data.html")

# %%
len(table_list1)
# Out:
# 4

# %%
table_list1=pd.read_html(r"data/sea_levels/Obtaining Tide Gauge Data.html")

# %%
len(table_list1)
# Out:
# 4

# %%
table_list1=pd.read_html("data/sea_levels/Obtaining\ Tide\ Gauge\ Data.html")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-065de76f4964> in <module>()
# ----> 1 table_list1=pd.read_html("data/sea_levels/Obtaining\ Tide\ Gauge\ Data.html")
#
# /usr/local/lib/python2.7/site-packages/pandas/io/html.pyc in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding)
#     868     _validate_header_arg(header)
#     869     return _parse(flavor, io, match, header, index_col, skiprows,
# --> 870                   parse_dates, tupleize_cols, thousands, attrs, encoding)
#
# /usr/local/lib/python2.7/site-packages/pandas/io/html.pyc in _parse(flavor, io, match, header, index_col, skiprows, parse_dates, tupleize_cols, thousands, attrs, encoding)
#     730             break
#     731     else:
# --> 732         raise_with_traceback(retained)
#     733
#     734     ret = []
#
# ...

# %%
table_list1=pd.read_html("data/sea_levels/Obtaining1.html")

# %%
len(table_list1)
# Out:
# 4

# %%
table_list1
# Out:
# [                                  0   \
#  0                                NaN
#  1                                NaN
#  2                                FEB
#  3                                NaN
#  4                               2014
#  5  58 captures  18 Apr 10 - 3 Apr 15
#
#                                                    1     2   \
#  0  FEB  APR  May  3  2014  2015  2016  58 capture...   NaN
#  1                 FEB  APR  May  3  2014  2015  2016   FEB
#  2                                                APR   May
#  3                                                  3   NaN
#  4                                               2015  2016
#  5                                                NaN   NaN
#
#                                     3    4    5    6   7       8       9   \
#  0  FEB  APR  May  3  2014  2015  2016  FEB  APR  May NaN     3.0     NaN
#  1                                 APR  May  NaN    3 NaN  2014.0  2015.0
# ...

# %%
local_sea_level_stations=table_list[-1]

# %%
local_sea_level_stations
# Out:
#                                   Station Name    ID    Lat.     Lon.  \
# 0                                     HELIGMAN   231  60.200   19.300
# 1                                 KOBBAKLINTAR    63  60.033   19.883
# 2                                     LEMSTROM    84  60.100   20.017
# 3                              FOGLO / DEGERBY   249  60.032   20.385
# 4                                    PAGO PAGO   539 -14.280 -170.690
# 5                              BAHIA ESPERANZA   988 -63.300  -56.917
# 6                            ARGENTINE ISLANDS   913 -65.246  -64.257
# 7                             PUERTO SOBERANIA  1603 -62.483  -59.633
# 8                              ALMIRANTE BROWN   858 -64.900  -62.867
# 9                      CAPE ROBERTS ANTARCTICA  1763 -77.034  163.191
# 10                                  SCOTT BASE  2029 -77.850  166.769
# 11                                     ROTHERA  1931 -67.571  -68.130
# ...

# %%
type(giss_temp)
# Out:
# pandas.core.frame.DataFrame

# %%
giss_temp.shape
# Out:
# (143, 20)

# %%
giss_temp.dtypes
# Out:
# Year      object
# Jan       object
# Feb       object
# Mar       object
# Apr       object
# May       object
# Jun       object
# Jul       object
# Aug       object
# Sep       object
# Oct       object
# Nov       object
# Dec       object
# J-D       object
# D-N       object
# DJF       object
# MAM       object
# JJA       object
# SON       object
# Year.1    object
# dtype: object

# %%
# %recall 42
# Out:
# Couldn't evaluate or find in history: 42

# %%
42

# %%
# %recall 25

# %%
giss_temp.shape

# %%
giss_temp
# Out:
#      Year  Jan  Feb  Mar  Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# 0    1880  -34  -27  -22  -30   -16   -24   -19   -12   -20   -19   -16   -21
# 1    1881  -13  -16   -2   -3    -3   -27   -12    -8   -18   -23   -28   -18
# 2    1882    3    4   -2  -24   -20   -32   -27   -11   -11   -25   -25   -37
# 3    1883  -38  -38  -12  -20   -20    -8    -3   -13   -19   -19   -28   -21
# 4    1884  -20  -14  -31  -36   -33   -36   -31   -24   -29   -25   -29   -25
# 5    1885  -57  -29  -19  -36   -35   -40   -28   -24   -17   -14   -14     0
# 6    1886  -37  -43  -34  -23   -21   -30   -13   -21   -12   -22   -29   -18
# 7    1887  -60  -43  -26  -34   -28   -25   -19   -28   -24   -33   -29   -40
# 8    1888  -43  -41  -39  -25   -26   -20   -11   -13   -10    -3    -1   -10
# 9    1889  -18   16    6    7    -1   -10   -13   -18   -18   -21   -32   -30
# 10   1890  -41  -37  -37  -34   -44   -29   -25   -33   -31   -21   -45   -30
# ...

# %%
giss_temp.columns
# Out:
# Index([u'Year', u'Jan', u'Feb', u'Mar', u'Apr', u'May', u'Jun', u'Jul', u'Aug',
#        u'Sep', u'Oct', u'Nov', u'Dec', u'J-D', u'D-N', u'DJF', u'MAM', u'JJA',
#        u'SON', u'Year.1'],
#       dtype='object')

# %%
giss_temp.index
# Out:
# RangeIndex(start=0, stop=143, step=1)

# %%
giss_temp[12].dtype
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-c6ec7b7cefef> in <module>()
# ----> 1 giss_temp[12].dtype
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1343         res = cache.get(item)
#    1344         if res is None:
# ...

# %%
giss_temp.info
# Out:
# <bound method DataFrame.info of      Year  Jan  Feb  Mar  Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec  \
# 0    1880  -34  -27  -22  -30   -16   -24   -19   -12   -20   -19   -16   -21
# 1    1881  -13  -16   -2   -3    -3   -27   -12    -8   -18   -23   -28   -18
# 2    1882    3    4   -2  -24   -20   -32   -27   -11   -11   -25   -25   -37
# 3    1883  -38  -38  -12  -20   -20    -8    -3   -13   -19   -19   -28   -21
# 4    1884  -20  -14  -31  -36   -33   -36   -31   -24   -29   -25   -29   -25
# 5    1885  -57  -29  -19  -36   -35   -40   -28   -24   -17   -14   -14     0
# 6    1886  -37  -43  -34  -23   -21   -30   -13   -21   -12   -22   -29   -18
# 7    1887  -60  -43  -26  -34   -28   -25   -19   -28   -24   -33   -29   -40
# 8    1888  -43  -41  -39  -25   -26   -20   -11   -13   -10    -3    -1   -10
# 9    1889  -18   16    6    7    -1   -10   -13   -18   -18   -21   -32   -30
# 10   1890  -41  -37  -37  -34   -44   -29   -25   -33   -31   -21   -45   -30
# ...

# %%
giss_temp.index
# Out:
# RangeIndex(start=0, stop=143, step=1)

# %%
pd.__version__
# Out:
# u'0.18.0'

# %%
type(full_globe_temp)
# Out:
# pandas.core.frame.DataFrame

# %%
full_globe_temp
# Out:
#                      mean temp
# year
# 1880-01-01 00:00:00    -0.1591
# 1881-01-01 00:00:00    -0.0789
# 1882-01-01 00:00:00    -0.1313
# 1883-01-01 00:00:00    -0.1675
# 1884-01-01 00:00:00    -0.2485
# 1885-01-01 00:00:00    -0.2042
# 1886-01-01 00:00:00    -0.1695
# 1887-01-01 00:00:00    -0.2505
# 1888-01-01 00:00:00    -0.1605
# 1889-01-01 00:00:00    -0.1103
# 1890-01-01 00:00:00    -0.3014
# 1891-01-01 00:00:00    -0.2527
# 1892-01-01 00:00:00    -0.2926
# 1893-01-01 00:00:00    -0.3274
# 1894-01-01 00:00:00    -0.2880
# 1895-01-01 00:00:00    -0.2146
# 1896-01-01 00:00:00    -0.1009
# 1897-01-01 00:00:00    -0.1294
# 1898-01-01 00:00:00    -0.2517
# 1899-01-01 00:00:00    -0.1356
# 1900-01-01             -0.1125
# 1901-01-01             -0.1693
# 1902-01-01             -0.2255
# 1903-01-01             -0.3442
# 1904-01-01             -0.3799
# 1905-01-01             -0.2583
# 1906-01-01             -0.2060
# 1907-01-01             -0.3726
# 1908-01-01             -0.3922
# ...

# %%
full_globe_temp.index
# Out:
# DatetimeIndex(['1880-01-01', '1881-01-01', '1882-01-01', '1883-01-01',
#                '1884-01-01', '1885-01-01', '1886-01-01', '1887-01-01',
#                '1888-01-01', '1889-01-01',
#                ...
#                '2001-01-01', '2002-01-01', '2003-01-01', '2004-01-01',
#                '2005-01-01', '2006-01-01', '2007-01-01', '2008-01-01',
#                '2009-01-01', '2010-01-01'],
#               dtype='datetime64[ns]', name=u'year', length=131, freq=None)

# %%
full_globe_temp.columns
# Out:
# Index([u'mean temp'], dtype='object')

# %%
full_globe_temp["mean temp"]
# Out:
# year
# 1880-01-01 00:00:00     -0.1591
# 1881-01-01 00:00:00     -0.0789
# 1882-01-01 00:00:00     -0.1313
# 1883-01-01 00:00:00     -0.1675
# 1884-01-01 00:00:00     -0.2485
# 1885-01-01 00:00:00     -0.2042
# 1886-01-01 00:00:00     -0.1695
# 1887-01-01 00:00:00     -0.2505
# 1888-01-01 00:00:00     -0.1605
# 1889-01-01 00:00:00     -0.1103
# 1890-01-01 00:00:00     -0.3014
# 1891-01-01 00:00:00     -0.2527
# 1892-01-01 00:00:00     -0.2926
# 1893-01-01 00:00:00     -0.3274
# 1894-01-01 00:00:00     -0.2880
# 1895-01-01 00:00:00     -0.2146
# 1896-01-01 00:00:00     -0.1009
# 1897-01-01 00:00:00     -0.1294
# 1898-01-01 00:00:00     -0.2517
# 1899-01-01 00:00:00     -0.1356
# 1900-01-01              -0.1125
# 1901-01-01              -0.1693
# 1902-01-01              -0.2255
# 1903-01-01              -0.3442
# 1904-01-01              -0.3799
# 1905-01-01              -0.2583
# 1906-01-01              -0.2060
# 1907-01-01              -0.3726
# 1908-01-01              -0.3922
# ...

# %%
full_globe_temp=full_globe_temp["mean temp"]

# %%
full_globe_temp
# Out:
# year
# 1880-01-01 00:00:00     -0.1591
# 1881-01-01 00:00:00     -0.0789
# 1882-01-01 00:00:00     -0.1313
# 1883-01-01 00:00:00     -0.1675
# 1884-01-01 00:00:00     -0.2485
# 1885-01-01 00:00:00     -0.2042
# 1886-01-01 00:00:00     -0.1695
# 1887-01-01 00:00:00     -0.2505
# 1888-01-01 00:00:00     -0.1605
# 1889-01-01 00:00:00     -0.1103
# 1890-01-01 00:00:00     -0.3014
# 1891-01-01 00:00:00     -0.2527
# 1892-01-01 00:00:00     -0.2926
# 1893-01-01 00:00:00     -0.3274
# 1894-01-01 00:00:00     -0.2880
# 1895-01-01 00:00:00     -0.2146
# 1896-01-01 00:00:00     -0.1009
# 1897-01-01 00:00:00     -0.1294
# 1898-01-01 00:00:00     -0.2517
# 1899-01-01 00:00:00     -0.1356
# 1900-01-01              -0.1125
# 1901-01-01              -0.1693
# 1902-01-01              -0.2255
# 1903-01-01              -0.3442
# 1904-01-01              -0.3799
# 1905-01-01              -0.2583
# 1906-01-01              -0.2060
# 1907-01-01              -0.3726
# 1908-01-01              -0.3922
# ...

# %%
full_globe_temp.dtypes
# Out:
# dtype('float64')

# %%
full_globe_temp.shape
# Out:
# (131,)

# %%
import matplotlib.pyplot as plt
from pandas import set_option
set_option("display.max_rows",16)
LARGE_FIGSIZE=(12,8)
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
southern_sea_level.columns
# Out:
# Index([u'year', u'msl_ib(mm)', u'#version_2016rel1'], dtype='object')

# %%
southern_sea_level.year
# Out:
# 0      1992.9323
# 1      1992.9595
# 2      1992.9866
# 3      1993.0138
# 4      1993.0409
# 5      1993.0681
# 6      1993.0952
# 7      1993.1223
#          ...
# 841    2015.8182
# 842    2015.8453
# 843    2015.8725
# 844    2015.8996
# 845    2015.9268
# 846    2015.9539
# 847    2015.9811
# 848    2016.0082
# Name: year, dtype: float64

# %%
southern_sea_level[year]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-40579ca74d2b> in <module>()
# ----> 1 southern_sea_level[year]
#
# NameError: name 'year' is not defined

# %%
southern_sea_level["year"]
# Out:
# 0      1992.9323
# 1      1992.9595
# 2      1992.9866
# 3      1993.0138
# 4      1993.0409
# 5      1993.0681
# 6      1993.0952
# 7      1993.1223
#          ...
# 841    2015.8182
# 842    2015.8453
# 843    2015.8725
# 844    2015.8996
# 845    2015.9268
# 846    2015.9539
# 847    2015.9811
# 848    2016.0082
# Name: year, dtype: float64

# %%
southern_sea_level.year==northern_sea_level.year
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
#        ...
# 841    True
# 842    True
# 843    True
# 844    True
# 845    True
# 846    True
# 847    True
# 848    True
# Name: year, dtype: bool

# %%
np.year(southern_sea_level.year==northern_sea_level.year)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-d1481c4b98f4> in <module>()
# ----> 1 np.year(southern_sea_level.year==northern_sea_level.year)
#
# AttributeError: 'module' object has no attribute 'year'

# %%
np.all(southern_sea_level.year==northern_sea_level.year)
# Out:
# True

# %%
np.all?

# %%
sea_level=pd.DataFrame({"northern_hem":northern_sea_level["msl_ib(mm)"],"southern_hem":southern_sea_level["msl_ib(mm)"],"date":northern_sea_level["year"]})

# %%
sea_level
# Out:
#           date  northern_hem  southern_hem
# 0    1992.9323        13.717         2.517
# 1    1992.9595         1.328        -7.645
# 2    1992.9866       -13.375        -2.267
# 3    1993.0138       -24.723         0.855
# 4    1993.0409       -29.231        -2.020
# 5    1993.0681       -32.538        -0.398
# 6    1993.0952       -35.588         4.102
# 7    1993.1223       -26.579         6.787
# ..         ...           ...           ...
# 841  2015.8182        92.405        74.234
# 842  2015.8453        81.278        72.443
# 843  2015.8725        79.341        67.228
# 844  2015.8996        78.108        74.586
# 845  2015.9268        76.599        77.518
# 846  2015.9539        69.691        77.618
# 847  2015.9811        59.957        76.646
# 848  2016.0082        46.712        77.585
#
# [849 rows x 3 columns]

# %%
mean_sea_level=pd.DataFrame({"northern_hem":northern_sea_level["msl_ib(mm)"].values,"southern_hem":southern_sea_level["msl_ib(mm)"].values, index=northern_sea_level.year})
# Out:
#   File "<ipython-input-57-0adc5a7137f1>", line 1
#     mean_sea_level=pd.DataFrame({"northern_hem":northern_sea_level["msl_ib(mm)"].values,"southern_hem":southern_sea_level["msl_ib(mm)"].values, index=northern_sea_level.year})
#                                                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
northern_sea_level["msl_ib(mm)l_ib(mm)"].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-447e2ff957e7> in <module>()
# ----> 1 northern_sea_level["msl_ib(mm)l_ib(mm)"].values
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1343         res = cache.get(item)
# ...

# %%
northern_sea_level.columns
# Out:
# Index([u'year', u'msl_ib(mm)', u'#version_2016rel1'], dtype='object')

# %%
northern_sea_level["msl_ib(mm)"]
# Out:
# 0      13.717
# 1       1.328
# 2     -13.375
# 3     -24.723
# 4     -29.231
# 5     -32.538
# 6     -35.588
# 7     -26.579
#         ...
# 841    92.405
# 842    81.278
# 843    79.341
# 844    78.108
# 845    76.599
# 846    69.691
# 847    59.957
# 848    46.712
# Name: msl_ib(mm), dtype: float64

# %%
northern_sea_level["msl_ib(mm)"].values
# Out:
# array([ 13.717,   1.328, -13.375, -24.723, -29.231, -32.538, -35.588,
#        -26.579, -29.622, -34.527, -34.25 , -28.518, -30.437, -21.371,
#        -19.196, -23.758, -23.628, -17.808, -10.085,  -2.12 ,  -1.728,
#         -4.942,   5.074,   0.386,  22.555,  22.201,  29.06 ,  23.325,
#         16.635,  21.488,  32.827,  34.992,  30.541,  18.24 ,   8.044,
#         10.529,  10.772,  10.732,   1.704,  -8.579, -14.764, -12.663,
#        -19.485, -23.443, -31.32 , -37.411, -35.844, -20.794, -29.478,
#        -24.542, -29.375, -26.85 , -25.8  , -18.381, -17.143, -13.169,
#        -12.817, -14.908,  -2.614,   5.727,  11.448,   8.972,  10.802,
#         13.665,  20.258,  34.426,  35.109,  24.421,  25.116,  18.954,
#         14.186,  19.882,  16.49 ,  -0.195,  -0.438,  -6.651, -12.734,
#        -16.869, -16.734, -24.215, -32.395, -37.79 , -30.054, -18.882,
#        -29.813, -30.159, -31.591, -28.16 , -16.628, -18.468, -15.211,
# ...

# %%
mean_sea_level=pd.DataFrame({"northern_hem":northern_sea_level["msl_ib(mm)"].values,"southern_hem":southern_sea_level["msl_ib(mm)"].values} index=northern_sea_level.year)
# Out:
#   File "<ipython-input-62-8fd30146b91b>", line 1
#     mean_sea_level=pd.DataFrame({"northern_hem":northern_sea_level["msl_ib(mm)"].values,"southern_hem":southern_sea_level["msl_ib(mm)"].values} index=northern_sea_level.year)
#                                                                                                                                                     ^
# SyntaxError: invalid syntax

# %%
mean_sea_level=pd.DataFrame({"northern_hem":northern_sea_level["msl_ib(mm)"].values,"southern_hem":southern_sea_level["msl_ib(mm)"].values},index=northern_sea_level.year)

# %%
mean_sea_level
# Out:
#            northern_hem  southern_hem
# year
# 1992.9323        13.717         2.517
# 1992.9595         1.328        -7.645
# 1992.9866       -13.375        -2.267
# 1993.0138       -24.723         0.855
# 1993.0409       -29.231        -2.020
# 1993.0681       -32.538        -0.398
# 1993.0952       -35.588         4.102
# 1993.1223       -26.579         6.787
# ...                 ...           ...
# 2015.8182        92.405        74.234
# 2015.8453        81.278        72.443
# 2015.8725        79.341        67.228
# 2015.8996        78.108        74.586
# 2015.9268        76.599        77.518
# 2015.9539        69.691        77.618
# 2015.9811        59.957        76.646
# 2016.0082        46.712        77.585
#
# [849 rows x 2 columns]

# %%
local_sea_level_stations.columns
# Out:
# Index([u'Station Name',           u'ID',         u'Lat.',         u'Lon.',
#            u'GLOSS ID',      u'Country',         u'Date',    u'Coastline',
#             u'Station'],
#       dtype='object')

# %%
local_sea_level_stations=[name.strip().replace(".","") for name in local_sea_level_stations.columns]

# %%
local_sea_level_stations=table_list[-1]

# %%
local_sea_level_stations.columns=[name.strip().replace(".","") for name in local_sea_level_stations.columns]

# %%
local_sea_level_stations
# Out:
#                  Station Name    ID     Lat      Lon  GLOSS ID Country  \
# 0                    HELIGMAN   231  60.200   19.300       NaN     ALA
# 1                KOBBAKLINTAR    63  60.033   19.883       NaN     ALA
# 2                    LEMSTROM    84  60.100   20.017       NaN     ALA
# 3             FOGLO / DEGERBY   249  60.032   20.385       NaN     ALA
# 4                   PAGO PAGO   539 -14.280 -170.690     144.0     ASM
# 5             BAHIA ESPERANZA   988 -63.300  -56.917     185.0     ATA
# 6           ARGENTINE ISLANDS   913 -65.246  -64.257     188.0     ATA
# 7            PUERTO SOBERANIA  1603 -62.483  -59.633     189.0     ATA
# ...                       ...   ...     ...      ...       ...     ...
# 1411                   DANANG  1475  16.100  108.217       NaN     VNM
# 1412                   HONNGU  1003  18.800  105.767       NaN     VNM
# 1413                   HONDAU   841  20.667  106.800       NaN     VNM
# ...

# %%
mean_sea_level.index.name="date"

# %%
mean_sea_level
# Out:
#            northern_hem  southern_hem
# date
# 1992.9323        13.717         2.517
# 1992.9595         1.328        -7.645
# 1992.9866       -13.375        -2.267
# 1993.0138       -24.723         0.855
# 1993.0409       -29.231        -2.020
# 1993.0681       -32.538        -0.398
# 1993.0952       -35.588         4.102
# 1993.1223       -26.579         6.787
# ...                 ...           ...
# 2015.8182        92.405        74.234
# 2015.8453        81.278        72.443
# 2015.8725        79.341        67.228
# 2015.8996        78.108        74.586
# 2015.9268        76.599        77.518
# 2015.9539        69.691        77.618
# 2015.9811        59.957        76.646
# 2016.0082        46.712        77.585
#
# [849 rows x 2 columns]

# %%
mean_sea_level.index
# Out:
# Float64Index([1992.9323, 1992.9595, 1992.9866, 1993.0138, 1993.0409, 1993.0681,
#               1993.0952, 1993.1223, 1993.1495, 1993.1766,
#               ...
#               2015.7639,  2015.791, 2015.8182, 2015.8453, 2015.8725, 2015.8996,
#               2015.9268, 2015.9539, 2015.9811, 2016.0082],
#              dtype='float64', name=u'date', length=849)

# %%
mean_sea_level.index.split(".")[-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-febfe81beb11> in <module>()
# ----> 1 mean_sea_level.index.split(".")[-1]
#
# AttributeError: 'Float64Index' object has no attribute 'split'

# %%
mean_sea_level.index[0]
# Out:
# 1992.9322999999999

# %%
mean_sea_level.index[0].split(".")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-1effb3326efe> in <module>()
# ----> 1 mean_sea_level.index[0].split(".")
#
# AttributeError: 'numpy.float64' object has no attribute 'split'

# %%
int(mean_sea_level.index[0])
# Out:
# 1992

# %%
int(mean_sea_level.index)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-3ded8f2a2113> in <module>()
# ----> 1 int(mean_sea_level.index)
#
# TypeError: int() argument must be a string or a number, not 'Float64Index'

# %%
[int(name) for name in mean_sea_level.index]
# Out:
# [1992,
#  1992,
#  1992,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1993,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1994,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
#  1995,
# ...

# %%
full_globe_temp==-999.00
# Out:
# year
# 1880-01-01 00:00:00    False
# 1881-01-01 00:00:00    False
# 1882-01-01 00:00:00    False
# 1883-01-01 00:00:00    False
# 1884-01-01 00:00:00    False
# 1885-01-01 00:00:00    False
# 1886-01-01 00:00:00    False
# 1887-01-01 00:00:00    False
#                        ...
# 2003-01-01             False
# 2004-01-01             False
# 2005-01-01             False
# 2006-01-01             False
# 2007-01-01             False
# 2008-01-01             False
# 2009-01-01             False
# 2010-01-01              True
# Name: mean temp, dtype: bool

# %%
full_globe_temp[full_globe_temp==-999.00]=np.nan

# %%
full_globe_temp.tail
# Out:
# <bound method Series.tail of year
# 1880-01-01 00:00:00   -0.1591
# 1881-01-01 00:00:00   -0.0789
# 1882-01-01 00:00:00   -0.1313
# 1883-01-01 00:00:00   -0.1675
# 1884-01-01 00:00:00   -0.2485
# 1885-01-01 00:00:00   -0.2042
# 1886-01-01 00:00:00   -0.1695
# 1887-01-01 00:00:00   -0.2505
#                         ...
# 2003-01-01             0.5818
# 2004-01-01             0.5416
# 2005-01-01             0.6154
# 2006-01-01             0.5601
# 2007-01-01             0.5472
# 2008-01-01             0.4804
# 2009-01-01             0.5551
# 2010-01-01                NaN
# Name: mean temp, dtype: float64>

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from pandas import set_option
set_option("display.max_rows", 16)
LARGE_FIGSIZE=(12,8)
global_sea_level=pd.read_table("http://sealevel.colorado.edu/files/2015_rel2/sl_ns_global.txt",sep='\s+')
northern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_nh.txt",sep='\s+')
southern_sea_level=pd.read_table("http://sealevel.colorado.edu/files/current/sl_sh.txt",sep='\s+')
filename="data/temperatures/annual.land_ocean.90S.90N.df_1901-2000mean.dat"
full_globe_temp=pd.read_table(filename,sep='\s+',names=["year","mean temp"],index_col=0,parse_dates=True)
co2=pd.read_table("data/greenhouse_gaz/co2_mm_global.txt",sep='\s+',parse_dates=[[0,1]])
giss_temp=pd.read_table("data/temperatures/GLB.Ts+dSST.txt",sep="\s+",skiprows=7,skip_footer=11,engine="python")
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
